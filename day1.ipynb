# %%
n1 = int(input("enter any number"))
n2 = int (input("enter any second number"))
add = n1+n1
add

# %%
n1 =int(input("enter any number"))
n2 = int(input("enter any number"))
mul = n1*n2
mul

# %%
n1 =int(input("enter any number"))
n2 = int(input("enter any number"))
sub = n1-n2
sub

# %%
n1 =float(input("enter any number"))
n2 = float(input("enter any number"))
div = n1/n2
div

# %%
n1 =int(input("enter any number"))
n2 = int(input("enter any number"))
sqr = n1**n2
sqr

# %%
# area of circle
r =int( input("enter value of r "))
pi = 3.14
area = pi*r*r
print(f"Area of circle is : {area}")

# %%
# area of triangal
h = int(input("enter value of height"))
b = int(input("enter the vlue of base"))
area_triangal = 1/2*h*b
print(f"area of triangalis :{area_triangal}")
# Out:
# enter value of height 12
# enter the vlue of base 15
# area of triangalis :90.0

# %%
# sqrroot progarm
x  = int(input("enter value of x "))
sqr_root = x**1/2
print(f"sqr root is :{sqr_root}")

# %%
# cube root program
x = int (input("enter a value of x"))
cube_root = x**1/3
print(f"cube roo is: {cube_root}")

# %%
# percentage
part = float(input("enter your number"))
total = float(input("enter total number"))
per = part*total/100
print(f"your percentage is= {per}%")
# Out:
# enter your number 45
# enter total number 70
# your percentage is= 31.5%

# %%
# simple interest
p = int(input("enter your principle amount"))
r = float(input("enter rate in percentage%"))
t = int(input("enter time in months"))
interest= p*r*t/100
print(f"simple interest is: {interest}")

# %%
print("welcome to bill calculater: \n ")
bill = float(input("what s your total bill: \n"))
tip = int(input("gives  much tip: \n"))
tip_percentage = float(tip/100)
total = (bill*tip_percentage)
total_bill = (bill+total)
split = int(input("which member are pay bill: \n"))
spilt_bill= (total_bill/split)
print(f"{spilt_bill}")
# Out:
# welcome to bill calculater:
# what s your total bill:
#  2000
# gives  much tip:
#  20
# which member are pay bill:
#  5
# 480.0
